# %% [markdown]
# # Example Notebook: Using the Model Libary
#
# This notebook is a quick example of how to use the library models. Ignore the issues with the loader class and instead use the data preprocessor class.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### Initial imports
import logging
import numpy as np
import pandas as pd
import pymc3 as pm
import theano.tensor as T
import matplotlib.pyplot as plt

logging.basicConfig(level=logging.INFO)
log = logging.getLogger(__name__)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from epimodel.pymc3_models.utils import geom_convolution
from epimodel.pymc3_models import cm_effect
from epimodel.pymc3_models.cm_effect.datapreprocessor import DataPreprocessor

# %matplotlib inline

# %%
regions = ["PT", "IS", "HU", "HR", "BE", "NL", "DK", "DE", "AT", "CZ", "GE", "FR", "ES", "GB", "PL", "GR", "CH", "FI", "NO", "SE", "SI", "SK"]
features = ['Gatherings limited to', 'Business suspended', 'Schools and universities closed', 'General curfew',
       'Healthcare specialisation', 'Phone line',
       'Asymptomatic contact isolation']

data = cm_effect.loader.Loader('2020-02-15', '2020-04-05', Regions, Features)

# Probability of being in Confirmed cases X days after transmission, from 0
# Generated from Poisson dist., must sum to 1.0
DelayProb = np.array([0.00, 0.01, 0.02, 0.06, 0.10, 0.13, 0.15, 0.15, 0.13, 0.10, 0.07, 0.05, 0.03])
print(f"Delayprob sum={DelayProb.sum()}, E[DP]={np.sum(DelayProb*np.arange(len(DelayProb)))}")
# Out:
# INFO:epimodel.regions:Name index has 6 potential conflicts: ['american samoa', 'georgia', 'guam', 'northern mariana islands', 'puerto rico', 'united states minor outlying islands']
# Delayprob sum=1.0, E[DP]=6.78

# %%
with cm_effect.models.CMModelV2(data) as model:
    model.build_all()
# Out:
# /Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/model.py:1430: ImputationWarning: Data in Observed contains missing values and will be automatically imputed from the sampling distribution.
#   warnings.warn(impute_message, ImputationWarning)
# INFO:epimodel.pymc3_models.cm_effect.models:Checking model test point
# INFO:epimodel.pymc3_models.cm_effect.models:
# CMReduction_log__            12.45
# BaseGrowthRate_log__         -1.61
# RegionGrowthRate_log__        6.27
# RegionScaleMult_log__       -20.22
# DailyGrowth_log__          1248.05
# InitialSize_log__           -70.87
# Observed_missing              0.00
# Observed                 -21899.64
# Name: Log-probability of test_point, dtype: float64

# %%
model.run(100)
# Out:
# Only 100 samples in chain.
# WARNING:pymc3:Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# INFO:pymc3:Initializing NUTS using adapt_diag...
# CMReduction_log__            12.45
# BaseGrowthRate_log__         -1.61
# RegionGrowthRate_log__        6.27
# RegionScaleMult_log__       -20.22
# DailyGrowth_log__          1248.05
# InitialSize_log__           -70.87
# Observed_missing              0.00
# Observed                 -21899.64
# Name: Log-probability of test_point, dtype: float64
# Multiprocess sampling (2 chains in 2 jobs)
# INFO:pymc3:Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [Observed_missing, InitialSize, DailyGrowth, RegionScaleMult, RegionGrowthRate, BaseGrowthRate, CMReduction]
# INFO:pymc3:NUTS: [Observed_missing, InitialSize, DailyGrowth, RegionScaleMult, RegionGrowthRate, BaseGrowthRate, CMReduction]
# Sampling 2 chains, 0 divergences:  17%|█▋        | 206/1200 [00:02<00:14, 69.29draws/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/parallel_sampling.py", line 110, in run
#     self._start_loop()
#   File "/Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/parallel_sampling.py", line 160, in _start_loop
#     point, stats = self._compute_point()
#   File "/Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/parallel_sampling.py", line 191, in _compute_point
#     point, stats = self._step_method.step(self._point)
#   File "/Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/step_methods/arraystep.py", line 247, in step
#     apoint, stats = self.astep(array)
#   File "/Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/step_methods/hmc/base_hmc.py", line 130, in astep
#     self.potential.raise_ok(self._logp_dlogp_func._ordering.vmap)
#   File "/Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/step_methods/hmc/quadpotential.py", line 231, in raise_ok
#     raise ValueError('\n'.join(errmsg))
# ValueError: Mass matrix contains zeros on the diagonal.
# The derivative of RV `Observed_missing`.ravel()[0] is zero.
# The derivative of RV `Observed_missing`.ravel()[1] is zero.
# The derivative of RV `Observed_missing`.ravel()[2] is zero.
# The derivative of RV `Observed_missing`.ravel()[3] is zero.
# The derivative of RV `Observed_missing`.ravel()[4] is zero.
# The derivative of RV `Observed_missing`.ravel()[5] is zero.
# The derivative of RV `Observed_missing`.ravel()[6] is zero.
# The derivative of RV `Observed_missing`.ravel()[7] is zero.
# The derivative of RV `Observed_missing`.ravel()[8] is zero.
# The derivative of RV `Observed_missing`.ravel()[9] is zero.
# The derivative of RV `Observed_missing`.ravel()[10] is zero.
# The derivative of RV `Observed_missing`.ravel()[11] is zero.
# The derivative of RV `Observed_missing`.ravel()[12] is zero.
# The derivative of RV `Observed_missing`.ravel()[13] is zero.
# The derivative of RV `Observed_missing`.ravel()[14] is zero.
# The derivative of RV `Observed_missing`.ravel()[15] is zero.
# The derivative of RV `Observed_missing`.ravel()[16] is zero.
# The derivative of RV `Observed_missing`.ravel()[17] is zero.
# The derivative of RV `Observed_missing`.ravel()[18] is zero.
# The derivative of RV `Observed_missing`.ravel()[19] is zero.
# The derivative of RV `Observed_missing`.ravel()[20] is zero.
# The derivative of RV `Observed_missing`.ravel()[21] is zero.
# The derivative of RV `Observed_missing`.ravel()[22] is zero.
# The derivative of RV `Observed_missing`.ravel()[23] is zero.
# The derivative of RV `Observed_missing`.ravel()[24] is zero.
# The derivative of RV `Observed_missing`.ravel()[25] is zero.
# The derivative of RV `Observed_missing`.ravel()[26] is zero.
# The derivative of RV `Observed_missing`.ravel()[27] is zero.
# The derivative of RV `Observed_missing`.ravel()[28] is zero.
# The derivative of RV `Observed_missing`.ravel()[29] is zero.
# The derivative of RV `Observed_missing`.ravel()[30] is zero.
# The derivative of RV `Observed_missing`.ravel()[31] is zero.
# The derivative of RV `Observed_missing`.ravel()[32] is zero.
# The derivative of RV `Observed_missing`.ravel()[33] is zero.
# The derivative of RV `Observed_missing`.ravel()[34] is zero.
# The derivative of RV `Observed_missing`.ravel()[35] is zero.
# The derivative of RV `Observed_missing`.ravel()[36] is zero.
# The derivative of RV `Observed_missing`.ravel()[37] is zero.
# The derivative of RV `Observed_missing`.ravel()[38] is zero.
# The derivative of RV `Observed_missing`.ravel()[39] is zero.
# The derivative of RV `Observed_missing`.ravel()[40] is zero.
# The derivative of RV `Observed_missing`.ravel()[41] is zero.
# The derivative of RV `Observed_missing`.ravel()[42] is zero.
# The derivative of RV `Observed_missing`.ravel()[43] is zero.
# The derivative of RV `Observed_missing`.ravel()[44] is zero.
# The derivative of RV `Observed_missing`.ravel()[45] is zero.
# The derivative of RV `Observed_missing`.ravel()[46] is zero.
# The derivative of RV `Observed_missing`.ravel()[47] is zero.
# The derivative of RV `Observed_missing`.ravel()[48] is zero.
# The derivative of RV `Observed_missing`.ravel()[49] is zero.
# The derivative of RV `Observed_missing`.ravel()[50] is zero.
# The derivative of RV `Observed_missing`.ravel()[51] is zero.
# The derivative of RV `Observed_missing`.ravel()[52] is zero.
# The derivative of RV `Observed_missing`.ravel()[53] is zero.
# The derivative of RV `Observed_missing`.ravel()[54] is zero.
# The derivative of RV `Observed_missing`.ravel()[55] is zero.
# The derivative of RV `Observed_missing`.ravel()[56] is zero.
# The derivative of RV `Observed_missing`.ravel()[57] is zero.
# The derivative of RV `Observed_missing`.ravel()[58] is zero.
# The derivative of RV `Observed_missing`.ravel()[59] is zero.
# The derivative of RV `Observed_missing`.ravel()[60] is zero.
# The derivative of RV `Observed_missing`.ravel()[61] is zero.
# The derivative of RV `Observed_missing`.ravel()[62] is zero.
# The derivative of RV `Observed_missing`.ravel()[63] is zero.
# The derivative of RV `Observed_missing`.ravel()[64] is zero.
# The derivative of RV `Observed_missing`.ravel()[65] is zero.
# The derivative of RV `Observed_missing`.ravel()[66] is zero.
# The derivative of RV `Observed_missing`.ravel()[67] is zero.
# The derivative of RV `Observed_missing`.ravel()[68] is zero.
# The derivative of RV `Observed_missing`.ravel()[69] is zero.
# The derivative of RV `Observed_missing`.ravel()[70] is zero.
# The derivative of RV `Observed_missing`.ravel()[71] is zero.
# The derivative of RV `Observed_missing`.ravel()[72] is zero.
# The derivative of RV `Observed_missing`.ravel()[73] is zero.
# The derivative of RV `Observed_missing`.ravel()[74] is zero.
# The derivative of RV `Observed_missing`.ravel()[75] is zero.
# The derivative of RV `Observed_missing`.ravel()[76] is zero.
# The derivative of RV `Observed_missing`.ravel()[77] is zero.
# The derivative of RV `Observed_missing`.ravel()[78] is zero.
# The derivative of RV `Observed_missing`.ravel()[79] is zero.
# The derivative of RV `Observed_missing`.ravel()[80] is zero.
# The derivative of RV `Observed_missing`.ravel()[81] is zero.
# The derivative of RV `Observed_missing`.ravel()[82] is zero.
# The derivative of RV `Observed_missing`.ravel()[83] is zero.
# The derivative of RV `Observed_missing`.ravel()[84] is zero.
# The derivative of RV `Observed_missing`.ravel()[85] is zero.
# The derivative of RV `Observed_missing`.ravel()[86] is zero.
# The derivative of RV `Observed_missing`.ravel()[87] is zero.
# The derivative of RV `Observed_missing`.ravel()[88] is zero.
# The derivative of RV `Observed_missing`.ravel()[89] is zero.
# The derivative of RV `Observed_missing`.ravel()[90] is zero.
# The derivative of RV `Observed_missing`.ravel()[91] is zero.
# The derivative of RV `Observed_missing`.ravel()[92] is zero.
# The derivative of RV `Observed_missing`.ravel()[93] is zero.
# The derivative of RV `Observed_missing`.ravel()[94] is zero.
# The derivative of RV `Observed_missing`.ravel()[95] is zero.
# The derivative of RV `Observed_missing`.ravel()[96] is zero.
# The derivative of RV `Observed_missing`.ravel()[97] is zero.
# The derivative of RV `Observed_missing`.ravel()[98] is zero.
# The derivative of RV `Observed_missing`.ravel()[99] is zero.
# The derivative of RV `Observed_missing`.ravel()[100] is zero.
# The derivative of RV `Observed_missing`.ravel()[101] is zero.
# The derivative of RV `Observed_missing`.ravel()[102] is zero.
# The derivative of RV `Observed_missing`.ravel()[103] is zero.
# The derivative of RV `Observed_missing`.ravel()[104] is zero.
# The derivative of RV `Observed_missing`.ravel()[105] is zero.
# The derivative of RV `Observed_missing`.ravel()[106] is zero.
# The derivative of RV `Observed_missing`.ravel()[107] is zero.
# The derivative of RV `Observed_missing`.ravel()[108] is zero.
# The derivative of RV `Observed_missing`.ravel()[109] is zero.
# The derivative of RV `Observed_missing`.ravel()[110] is zero.
# The derivative of RV `Observed_missing`.ravel()[111] is zero.
# The derivative of RV `Observed_missing`.ravel()[112] is zero.
# The derivative of RV `Observed_missing`.ravel()[113] is zero.
# The derivative of RV `Observed_missing`.ravel()[114] is zero.
# The derivative of RV `Observed_missing`.ravel()[115] is zero.
# The derivative of RV `Observed_missing`.ravel()[116] is zero.
# The derivative of RV `Observed_missing`.ravel()[117] is zero.
# The derivative of RV `Observed_missing`.ravel()[118] is zero.
# The derivative of RV `Observed_missing`.ravel()[119] is zero.
# The derivative of RV `Observed_missing`.ravel()[120] is zero.
# The derivative of RV `Observed_missing`.ravel()[121] is zero.
# The derivative of RV `Observed_missing`.ravel()[122] is zero.
# The derivative of RV `Observed_missing`.ravel()[123] is zero.
# The derivative of RV `Observed_missing`.ravel()[124] is zero.
# The derivative of RV `Observed_missing`.ravel()[125] is zero.
# The derivative of RV `Observed_missing`.ravel()[126] is zero.
# The derivative of RV `Observed_missing`.ravel()[127] is zero.
# The derivative of RV `Observed_missing`.ravel()[128] is zero.
# The derivative of RV `Observed_missing`.ravel()[129] is zero.
# The derivative of RV `Observed_missing`.ravel()[130] is zero.
# The derivative of RV `Observed_missing`.ravel()[131] is zero.
# The derivative of RV `Observed_missing`.ravel()[132] is zero.
# The derivative of RV `Observed_missing`.ravel()[133] is zero.
# The derivative of RV `Observed_missing`.ravel()[134] is zero.
# The derivative of RV `Observed_missing`.ravel()[135] is zero.
# The derivative of RV `Observed_missing`.ravel()[136] is zero.
# The derivative of RV `Observed_missing`.ravel()[137] is zero.
# The derivative of RV `Observed_missing`.ravel()[138] is zero.
# The derivative of RV `Observed_missing`.ravel()[139] is zero.
# The derivative of RV `Observed_missing`.ravel()[140] is zero.
# The derivative of RV `Observed_missing`.ravel()[141] is zero.
# The derivative of RV `Observed_missing`.ravel()[142] is zero.
# The derivative of RV `Observed_missing`.ravel()[143] is zero.
# The derivative of RV `Observed_missing`.ravel()[144] is zero.
# The derivative of RV `Observed_missing`.ravel()[145] is zero.
# The derivative of RV `Observed_missing`.ravel()[146] is zero.
# The derivative of RV `Observed_missing`.ravel()[147] is zero.
# The derivative of RV `Observed_missing`.ravel()[148] is zero.
# The derivative of RV `Observed_missing`.ravel()[149] is zero.
# The derivative of RV `Observed_missing`.ravel()[150] is zero.
# The derivative of RV `Observed_missing`.ravel()[151] is zero.
# The derivative of RV `Observed_missing`.ravel()[152] is zero.
# The derivative of RV `Observed_missing`.ravel()[153] is zero.
# The derivative of RV `Observed_missing`.ravel()[154] is zero.
# The derivative of RV `Observed_missing`.ravel()[155] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[0] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[1] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[2] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[3] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[4] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[5] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[6] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[7] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[8] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[9] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[10] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[11] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[12] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[13] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[14] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[15] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[16] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[17] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[18] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[19] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[20] is zero.
# The derivative of RV `InitialSize_log__`.ravel()[21] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[0] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[1] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[2] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[3] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[4] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[5] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[6] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[7] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[8] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[9] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[10] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[11] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[12] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[13] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[14] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[15] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[16] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[17] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[18] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[19] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[20] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[21] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[22] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[23] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[24] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[25] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[26] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[27] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[28] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[29] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[30] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[31] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[32] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[33] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[34] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[35] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[36] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[37] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[38] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[39] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[40] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[41] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[42] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[43] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[44] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[45] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[46] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[47] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[48] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[49] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[50] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[51] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[52] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[53] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[54] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[55] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[56] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[57] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[58] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[59] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[60] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[61] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[62] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[63] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[64] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[65] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[66] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[67] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[68] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[69] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[70] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[71] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[72] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[73] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[74] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[75] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[76] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[77] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[78] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[79] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[80] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[81] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[82] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[83] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[84] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[85] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[86] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[87] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[88] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[89] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[90] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[91] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[92] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[93] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[94] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[95] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[96] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[97] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[98] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[99] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[100] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[101] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[102] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[103] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[104] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[105] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[106] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[107] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[108] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[109] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[110] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[111] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[112] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[113] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[114] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[115] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[116] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[117] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[118] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[119] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[120] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[121] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[122] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[123] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[124] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[125] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[126] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[127] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[128] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[129] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[130] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[131] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[132] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[133] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[134] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[135] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[136] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[137] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[138] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[139] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[140] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[141] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[142] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[143] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[144] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[145] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[146] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[147] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[148] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[149] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[150] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[151] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[152] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[153] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[154] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[155] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[156] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[157] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[158] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[159] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[160] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[161] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[162] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[163] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[164] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[165] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[166] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[167] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[168] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[169] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[170] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[171] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[172] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[173] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[174] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[175] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[176] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[177] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[178] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[179] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[180] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[181] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[182] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[183] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[184] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[185] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[186] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[187] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[188] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[189] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[190] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[191] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[192] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[193] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[194] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[195] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[196] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[197] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[198] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[199] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[200] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[201] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[202] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[203] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[204] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[205] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[206] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[207] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[208] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[209] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[210] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[211] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[212] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[213] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[214] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[215] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[216] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[217] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[218] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[219] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[220] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[221] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[222] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[223] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[224] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[225] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[226] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[227] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[228] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[229] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[230] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[231] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[232] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[233] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[234] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[235] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[236] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[237] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[238] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[239] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[240] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[241] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[242] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[243] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[244] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[245] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[246] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[247] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[248] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[249] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[250] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[251] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[252] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[253] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[254] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[255] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[256] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[257] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[258] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[259] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[260] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[261] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[262] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[263] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[264] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[265] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[266] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[267] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[268] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[269] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[270] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[271] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[272] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[273] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[274] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[275] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[276] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[277] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[278] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[279] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[280] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[281] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[282] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[283] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[284] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[285] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[286] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[287] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[288] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[289] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[290] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[291] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[292] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[293] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[294] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[295] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[296] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[297] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[298] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[299] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[300] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[301] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[302] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[303] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[304] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[305] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[306] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[307] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[308] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[309] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[310] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[311] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[312] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[313] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[314] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[315] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[316] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[317] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[318] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[319] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[320] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[321] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[322] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[323] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[324] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[325] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[326] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[327] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[328] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[329] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[330] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[331] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[332] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[333] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[334] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[335] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[336] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[337] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[338] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[339] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[340] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[341] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[342] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[343] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[344] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[345] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[346] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[347] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[348] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[349] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[350] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[351] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[352] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[353] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[354] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[355] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[356] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[357] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[358] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[359] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[360] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[361] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[362] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[363] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[364] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[365] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[366] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[367] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[368] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[369] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[370] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[371] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[372] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[373] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[374] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[375] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[376] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[377] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[378] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[379] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[380] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[381] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[382] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[383] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[384] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[385] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[386] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[387] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[388] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[389] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[390] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[391] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[392] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[393] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[394] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[395] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[396] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[397] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[398] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[399] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[400] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[401] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[402] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[403] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[404] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[405] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[406] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[407] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[408] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[409] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[410] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[411] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[412] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[413] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[414] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[415] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[416] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[417] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[418] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[419] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[420] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[421] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[422] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[423] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[424] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[425] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[426] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[427] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[428] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[429] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[430] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[431] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[432] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[433] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[434] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[435] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[436] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[437] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[438] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[439] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[440] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[441] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[442] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[443] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[444] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[445] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[446] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[447] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[448] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[449] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[450] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[451] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[452] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[453] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[454] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[455] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[456] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[457] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[458] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[459] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[460] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[461] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[462] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[463] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[464] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[465] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[466] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[467] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[468] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[469] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[470] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[471] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[472] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[473] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[474] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[475] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[476] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[477] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[478] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[479] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[480] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[481] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[482] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[483] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[484] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[485] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[486] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[487] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[488] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[489] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[490] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[491] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[492] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[493] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[494] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[495] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[496] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[497] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[498] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[499] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[500] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[501] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[502] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[503] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[504] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[505] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[506] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[507] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[508] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[509] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[510] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[511] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[512] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[513] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[514] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[515] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[516] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[517] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[518] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[519] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[520] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[521] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[522] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[523] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[524] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[525] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[526] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[527] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[528] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[529] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[530] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[531] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[532] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[533] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[534] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[535] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[536] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[537] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[538] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[539] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[540] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[541] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[542] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[543] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[544] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[545] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[546] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[547] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[548] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[549] is zero.
# ...
# The derivative of RV `DailyGrowth_log__`.ravel()[721] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[722] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[723] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[724] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[725] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[726] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[727] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[728] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[729] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[730] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[731] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[732] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[733] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[734] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[735] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[736] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[737] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[738] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[739] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[740] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[741] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[742] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[743] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[744] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[745] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[746] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[747] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[748] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[749] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[750] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[751] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[752] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[753] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[754] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[755] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[756] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[757] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[758] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[759] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[760] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[761] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[762] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[763] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[764] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[765] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[766] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[767] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[768] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[769] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[770] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[771] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[772] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[773] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[774] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[775] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[776] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[777] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[778] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[779] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[780] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[781] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[782] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[783] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[784] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[785] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[786] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[787] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[788] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[789] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[790] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[791] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[792] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[793] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[794] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[795] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[796] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[797] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[798] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[799] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[800] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[801] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[802] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[803] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[804] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[805] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[806] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[807] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[808] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[809] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[810] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[811] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[812] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[813] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[814] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[815] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[816] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[817] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[818] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[819] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[820] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[821] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[822] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[823] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[824] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[825] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[826] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[827] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[828] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[829] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[830] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[831] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[832] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[833] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[834] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[835] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[836] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[837] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[838] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[839] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[840] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[841] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[842] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[843] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[844] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[845] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[846] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[847] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[848] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[849] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[850] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[851] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[852] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[853] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[854] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[855] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[856] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[857] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[858] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[859] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[860] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[861] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[862] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[863] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[864] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[865] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[866] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[867] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[868] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[869] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[870] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[871] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[872] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[873] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[874] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[875] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[876] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[877] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[878] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[879] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[880] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[881] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[882] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[883] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[884] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[885] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[886] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[887] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[888] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[889] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[890] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[891] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[892] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[893] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[894] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[895] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[896] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[897] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[898] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[899] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[900] is zero.
# The derivative of RV `DailyGrowth_log__`.ravel()[901] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[0] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[1] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[2] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[3] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[4] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[5] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[6] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[7] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[8] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[9] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[10] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[11] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[12] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[13] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[14] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[15] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[16] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[17] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[18] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[19] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[20] is zero.
# The derivative of RV `RegionScaleMult_log__`.ravel()[21] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[0] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[1] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[2] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[3] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[4] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[5] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[6] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[7] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[8] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[9] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[10] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[11] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[12] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[13] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[14] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[15] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[16] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[17] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[18] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[19] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[20] is zero.
# The derivative of RV `RegionGrowthRate_log__`.ravel()[21] is zero.
# The derivative of RV `BaseGrowthRate_log__`.ravel()[0] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[0] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[1] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[2] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[3] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[4] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[5] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[6] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[7] is zero.
# The derivative of RV `CMReduction_log__`.ravel()[8] is zero.
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/mrinank/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/parallel_sampling.py", line 117, in run
#     self._msg_pipe.send(("error", None, e))
#   File "/usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 206, in send
#     self._send_bytes(_ForkingPickler.dumps(obj))
#   File "/usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 398, in _send_bytes
#     self._send(buf)
#   File "/usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# KeyboardInterrupt

# %%
regions = ["PT", "IS", "HU", "HR", "BE", "NL", "DK", "DE", "AT", "CZ", "GE", "FR", "ES", "GB", "PL", "GR", "CH", "FI", "NO", "SE", "SI", "SK"]
features = ['Gatherings limited to', 'Business suspended', 'Schools and universities closed', 'General curfew',
       'Healthcare specialisation', 'Phone line', 'Asymptomatic contact isolation']

dp = DataPreprocessor()
data = dp.preprocess_data("../../data", regions, features)

# Probability of being in Confirmed cases X days after transmission, from 0
# Generated from Poisson dist., must sum to 1.0
DelayProb = np.array([0.00, 0.01, 0.02, 0.06, 0.10, 0.13, 0.15, 0.15, 0.13, 0.10, 0.07, 0.05, 0.03])
print(f"Delayprob sum={DelayProb.sum()}, E[DP]={np.sum(DelayProb*np.arange(len(DelayProb)))}")
# Out:
# INFO:epimodel.regions:Name index has 6 potential conflicts: ['american samoa', 'georgia', 'guam', 'northern mariana islands', 'puerto rico', 'united states minor outlying islands']
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor:
# Countermeasures                               min   .. mean  .. max
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor: 0 Gatherings limited to                      0.000 .. 0.177 .. 0.982
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor: 1 Business suspended                         0.000 .. 0.273 .. 1.000
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor: 2 Schools and universities closed            0.000 .. 0.361 .. 1.000
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor: 3 General curfew                             0.000 .. 0.167 .. 1.000
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor: 4 Healthcare specialisation                  0.000 .. 0.020 .. 0.429
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor: 5 Phone line                                 0.000 .. 0.032 .. 1.000
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor: 6 Asymptomatic contact isolation             0.000 .. 0.053 .. 1.000
# INFO:epimodel.pymc3_models.cm_effect.datapreprocessor:Data Preprocessing Complete using:
#
# {
#     "start_date": "2020-2-10",
#     "end_date": "2020-04-05",
#     "min_final_num_active_cases": 100,
#     "min_num_active_mask": 10,
#     "min_num_confirmed_mask": 10
# }
# Delayprob sum=1.0, E[DP]=6.78

# %%
with cm_effect.models.CMModelV2(data) as model2:
    model2.build_all()
# Out:
# INFO:epimodel.pymc3_models.cm_effect.models:Checking model test point
# INFO:epimodel.pymc3_models.cm_effect.models:
# CMReduction_log__             9.69
# BaseGrowthRate_log__         -1.61
# RegionGrowthRate_log__        6.27
# RegionScaleMult_log__       -20.22
# DailyGrowth_log__          1400.25
# InitialSize_log__           -70.87
# Observed_missing              0.00
# Observed                 -15098.43
# Name: Log-probability of test_point, dtype: float64

# %%
model2.run(100)
# Out:
# Only 100 samples in chain.
# WARNING:pymc3:Only 100 samples in chain.
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# INFO:pymc3:Initializing NUTS using adapt_diag...
# CMReduction_log__             9.69
# BaseGrowthRate_log__         -1.61
# RegionGrowthRate_log__        6.27
# RegionScaleMult_log__       -20.22
# DailyGrowth_log__          1400.25
# InitialSize_log__           -70.87
# Observed_missing              0.00
# Observed                 -15098.43
# Name: Log-probability of test_point, dtype: float64
# Multiprocess sampling (2 chains in 2 jobs)
# INFO:pymc3:Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [Observed_missing, InitialSize, DailyGrowth, RegionScaleMult, RegionGrowthRate, BaseGrowthRate, CMReduction]
# INFO:pymc3:NUTS: [Observed_missing, InitialSize, DailyGrowth, RegionScaleMult, RegionGrowthRate, BaseGrowthRate, CMReduction]
# Sampling 2 chains, 10 divergences: 100%|██████████| 1200/1200 [02:08<00:00,  9.34draws/s]
# There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# ERROR:pymc3:There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# ERROR:pymc3:The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The number of effective samples is smaller than 10% for some parameters.
# WARNING:pymc3:The number of effective samples is smaller than 10% for some parameters.

# %%
_ = model2.plot_traces()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-374792838548> in <module>
# ----> 1 _ = model2.plot_traces()
#
# ~/workspace/epidemicforecasting/epimodel/epimodel/pymc3_models/cm_effect/models.py in plot_traces(self)
#      74     def plot_traces(self):
#      75         assert self.trace is not None
# ---> 76         return pm.traceplot(self.trace, var_names=list(self.plot_trace_vars))
#      77
#      78     def plot_effect(self):
#
# ~/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/plots/__init__.py in wrapped(*args, **kwargs)
#      21                 warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
#      22                 kwargs[new] = kwargs.pop(old)
# ---> 23             return func(*args, **kwargs)
#      24     return wrapped
#      25
#
# ~/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/pymc3/plots/__init__.py in traceplot(*args, **kwargs)
#      39     try:
#      40         kwargs.setdefault('compact', True)
# ---> 41         return az.plot_trace(*args, **kwargs)
#      42     except TypeError:
#      43         kwargs.pop('compact')
#
# ~/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/arviz/plots/traceplot.py in plot_trace(data, var_names, transform, coords, divergences, figsize, rug, lines, compact, compact_prop, combined, chain_prop, legend, plot_kwargs, fill_kwargs, rug_kwargs, hist_kwargs, trace_kwargs, ax, backend, backend_config, backend_kwargs, show)
#     274
#     275     plot = get_plotting_function("plot_trace", "traceplot", backend)
# --> 276     axes = plot(**trace_plot_args)
#     277
#     278     return axes
#
# ~/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/traceplot.py in plot_trace(data, var_names, divergences, figsize, rug, lines, compact_prop, combined, chain_prop, legend, plot_kwargs, fill_kwargs, rug_kwargs, hist_kwargs, trace_kwargs, plotters, divergence_data, axes, backend_kwargs, show)
#     202                     plot_kwargs,
#     203                     fill_kwargs,
# --> 204                     rug_kwargs,
#     205                 )
#     206                 if legend:
#
# ~/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/traceplot.py in _plot_chains_mpl(axes, idx, value, data, chain_prop, combined, xt_labelsize, rug, trace_kwargs, hist_kwargs, plot_kwargs, fill_kwargs, rug_kwargs)
#     321     for chain_idx, row in enumerate(value):
#     322         axes[idx, 1].plot(
# --> 323             data.draw.values, row, **{chain_prop[0]: chain_prop[1][chain_idx]}, **trace_kwargs
#     324         )
#     325
#
# ~/Library/Caches/pypoetry/virtualenvs/epimodel-H-ywULmv-py3.7/lib/python3.7/site-packages/xarray/core/common.py in __getattr__(self, name)
#     228             # __setstate__ attribute before the xarray object is initialized
#     229             for source in self._attr_sources:
# --> 230                 with suppress(KeyError):
#     231                     return source[name]
#     232         raise AttributeError(
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py in __enter__(self)
#     353         self._exceptions = exceptions
#     354
# --> 355     def __enter__(self):
#     356         pass
#     357
#
# KeyboardInterrupt:

# %% [markdown]
# Conclusions:
# * there seems to be some issue with the loader class, I reverted to the DataPreprocessor Class that I wrote.
# * I also had issues when including "'Phone line', 'Asymptomatic contact isolation'", yet to test whether this is a bug in the loader class or elsewhere.
# * the trace plot takes ages - maybe reduce number of variables plotted. I was lazy before, thats why it isn't complete
